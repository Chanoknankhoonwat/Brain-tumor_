# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanoknankhoonwat/Brain-tumor_/blob/main/Brain_Tumor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.13)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.12.0)

# %%
# !pip install visualkeras


import zipfile

import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from collections import Counter

import tensorflow as tf
import visualkeras
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD
from tensorflow.python.keras.optimizer_v2.adam import Adam

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dense, BatchNormalization,LayerNormalization,UnitNormalization
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D, AveragePooling2D
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (8.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.22.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
from google.colab import drive #case mounted gdrive
drive.mount('/content/gdrive', force_remount=False)
import os  #case connect via OS
os.chdir("/content/gdrive/")
os.getcwd()
# Out:
# Mounted at /content/gdrive
# '/content/gdrive'

# %%
folder_path = "/content/gdrive/MyDrive/Colab Notebooks/brain_tumor_dataset"
no_images = os.listdir(folder_path + '/no/')
yes_images = os.listdir(folder_path + '/yes/')
dataset=[]
lab=[]

for image_name in no_images:
    image=cv2.imread(folder_path + '/no/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(0)

for image_name in yes_images:
    image=cv2.imread(folder_path + '/yes/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(1)

# %%
dataset = np.array(dataset)
lab = np.array(lab)
print(dataset.shape, lab.shape)
# Out:
# (253, 240, 240, 3) (253,)

# %%
def plot_state(state):
    plt.figure(figsize= (12,12))
    for i in range(1, 10, 1):
        plt.subplot(3,3,i)
        img = load_img(folder_path + "/" + state + "/" + os.listdir(folder_path + "/" + state)[i], target_size=(pic_size, pic_size))
        plt.imshow(img)
    plt.show()

# %%
plot_state('yes')

# %%
plot_state("no")

# %%
#dataset = dataset/255

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset, lab, test_size=0.3, shuffle=True, random_state=42)

# %%
norm = Normalization()
norm.adapt(x_train)
norm.adapt(x_test)

model = Sequential()

model.add(Conv2D(filters=32,kernel_size=(3,3),strides=(2,2), activation="relu", padding="valid",input_shape=(240,240,3)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(LayerNormalization())

model.add(Conv2D(filters=32,kernel_size=(3,3),strides=(2,2), activation="relu", padding="valid"))
model.add(MaxPooling2D((2, 2)))

model.add(BatchNormalization())
model.add(Flatten())
model.add(Dropout(0.2))

model.add(Dense(units=64, activation='relu'))
    # kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
    # bias_regularizer=regularizers.L2(1e-4),
    # activity_regularizer=regularizers.L2(1e-5)

#Regularizers is an optimization to give penalty to neuron per-layer **in this case I used it instead of Dropout

model.add(Dense(1, activation='sigmoid'))

# %%
opt = Adam(learning_rate=1e-3)
model.compile(optimizer = opt, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 119, 119, 32)      896
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 59, 59, 32)        0
# _________________________________________________________________
# module_wrapper (ModuleWrappe (None, 59, 59, 32)        128
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 59, 59, 32)        64
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 29, 29, 32)        9248
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 14, 14, 32)        128
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6272)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                401472
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 412,001
# Trainable params: 411,873
# Non-trainable params: 128
# _________________________________________________________________

# %%
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1183x671 at 0x7B8884760640>

# %%
class_weights = class_weight.compute_class_weight(class_weight = "balanced", classes= np.unique(y_train), y= y_train)
class_weights = dict(zip(np.unique(y_train), class_weights))
class_weights
#class weight
# Out:
# {0: 1.2291666666666667, 1: 0.8428571428571429}

# %%
history = model.fit(x_train,y_train,batch_size=32 ,epochs = 100, class_weight=class_weights, validation_data=(x_test, y_test),verbose=1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 5s 650ms/step - loss: 1.0297 - accuracy: 0.5932 - val_loss: 0.6452 - val_accuracy: 0.5395
# Epoch 2/100
# 6/6 [==============================] - 5s 887ms/step - loss: 0.4831 - accuracy: 0.7797 - val_loss: 0.9646 - val_accuracy: 0.4737
# Epoch 3/100
# 6/6 [==============================] - 3s 549ms/step - loss: 0.3490 - accuracy: 0.8644 - val_loss: 1.4111 - val_accuracy: 0.3816
# Epoch 4/100
# 6/6 [==============================] - 3s 573ms/step - loss: 0.3025 - accuracy: 0.8588 - val_loss: 2.4945 - val_accuracy: 0.3421
# Epoch 5/100
# 6/6 [==============================] - 4s 672ms/step - loss: 0.1596 - accuracy: 0.9492 - val_loss: 1.9672 - val_accuracy: 0.3421
# Epoch 6/100
# 6/6 [==============================] - 5s 761ms/step - loss: 0.0835 - accuracy: 0.9661 - val_loss: 2.4738 - val_accuracy: 0.3421
# Epoch 7/100
# 6/6 [==============================] - 3s 571ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 2.0281 - val_accuracy: 0.3816
# Epoch 8/100
# 6/6 [==============================] - 3s 572ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.7657 - val_accuracy: 0.3947
# Epoch 9/100
# 6/6 [==============================] - 5s 803ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 1.4364 - val_accuracy: 0.4474
# Epoch 10/100
# 6/6 [==============================] - 4s 638ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.8555 - val_accuracy: 0.6579
# Epoch 11/100
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.7165 - val_accuracy: 0.6974
# Epoch 12/100
# 6/6 [==============================] - 3s 563ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.1216 - val_accuracy: 0.5789
# Epoch 13/100
# 6/6 [==============================] - 5s 928ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.2189 - val_accuracy: 0.5263
# Epoch 14/100
# 6/6 [==============================] - 4s 569ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0415 - val_accuracy: 0.6053
# Epoch 15/100
# 6/6 [==============================] - 3s 568ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.8503 - val_accuracy: 0.6842
# Epoch 16/100
# 6/6 [==============================] - 3s 575ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.8523 - val_accuracy: 0.6842
# Epoch 17/100
# 6/6 [==============================] - 5s 876ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9217 - val_accuracy: 0.6842
# Epoch 18/100
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9543 - val_accuracy: 0.6842
# Epoch 19/100
# 6/6 [==============================] - 3s 571ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9404 - val_accuracy: 0.6842
# Epoch 20/100
# 6/6 [==============================] - 4s 694ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8458 - val_accuracy: 0.6842
# Epoch 21/100
# 6/6 [==============================] - 5s 742ms/step - loss: 9.7097e-04 - accuracy: 1.0000 - val_loss: 0.7278 - val_accuracy: 0.7105
# Epoch 22/100
# 6/6 [==============================] - 3s 579ms/step - loss: 9.3724e-04 - accuracy: 1.0000 - val_loss: 0.6442 - val_accuracy: 0.7763
# Epoch 23/100
# 6/6 [==============================] - 3s 566ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6127 - val_accuracy: 0.7763
# Epoch 24/100
# 6/6 [==============================] - 5s 831ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6480 - val_accuracy: 0.7763
# Epoch 25/100
# 6/6 [==============================] - 4s 620ms/step - loss: 9.4603e-04 - accuracy: 1.0000 - val_loss: 0.6680 - val_accuracy: 0.7500
# Epoch 26/100
# 6/6 [==============================] - 3s 564ms/step - loss: 7.3999e-04 - accuracy: 1.0000 - val_loss: 0.6594 - val_accuracy: 0.7500
# Epoch 27/100
# 6/6 [==============================] - 3s 552ms/step - loss: 9.5673e-04 - accuracy: 1.0000 - val_loss: 0.6375 - val_accuracy: 0.7895
# Epoch 28/100
# 6/6 [==============================] - 5s 966ms/step - loss: 8.0505e-04 - accuracy: 1.0000 - val_loss: 0.5753 - val_accuracy: 0.7895
# Epoch 29/100
# 6/6 [==============================] - 3s 555ms/step - loss: 7.8281e-04 - accuracy: 1.0000 - val_loss: 0.5520 - val_accuracy: 0.8026
# Epoch 30/100
# 6/6 [==============================] - 3s 571ms/step - loss: 6.8002e-04 - accuracy: 1.0000 - val_loss: 0.5492 - val_accuracy: 0.7895
# Epoch 31/100
# 6/6 [==============================] - 4s 616ms/step - loss: 5.1857e-04 - accuracy: 1.0000 - val_loss: 0.5441 - val_accuracy: 0.7895
# Epoch 32/100
# 6/6 [==============================] - 5s 838ms/step - loss: 5.6730e-04 - accuracy: 1.0000 - val_loss: 0.5292 - val_accuracy: 0.7895
# Epoch 33/100
# 6/6 [==============================] - 3s 560ms/step - loss: 5.0273e-04 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.7763
# Epoch 34/100
# 6/6 [==============================] - 3s 560ms/step - loss: 5.0434e-04 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.7763
# Epoch 35/100
# 6/6 [==============================] - 4s 745ms/step - loss: 5.2518e-04 - accuracy: 1.0000 - val_loss: 0.4938 - val_accuracy: 0.7632
# Epoch 36/100
# 6/6 [==============================] - 4s 698ms/step - loss: 4.5191e-04 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.7632
# Epoch 37/100
# 6/6 [==============================] - 4s 668ms/step - loss: 5.0858e-04 - accuracy: 1.0000 - val_loss: 0.4814 - val_accuracy: 0.7763
# Epoch 38/100
# 6/6 [==============================] - 5s 857ms/step - loss: 4.9709e-04 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.7763
# Epoch 39/100
# 6/6 [==============================] - 5s 796ms/step - loss: 3.9885e-04 - accuracy: 1.0000 - val_loss: 0.5130 - val_accuracy: 0.7632
# Epoch 40/100
# 6/6 [==============================] - 3s 568ms/step - loss: 4.5573e-04 - accuracy: 1.0000 - val_loss: 0.5260 - val_accuracy: 0.7632
# Epoch 41/100
# 6/6 [==============================] - 3s 555ms/step - loss: 4.8414e-04 - accuracy: 1.0000 - val_loss: 0.4751 - val_accuracy: 0.7895
# Epoch 42/100
# 6/6 [==============================] - 4s 770ms/step - loss: 4.2372e-04 - accuracy: 1.0000 - val_loss: 0.4517 - val_accuracy: 0.7895
# Epoch 43/100
# 6/6 [==============================] - 4s 626ms/step - loss: 3.7040e-04 - accuracy: 1.0000 - val_loss: 0.4516 - val_accuracy: 0.7895
# Epoch 44/100
# 6/6 [==============================] - 3s 541ms/step - loss: 4.0158e-04 - accuracy: 1.0000 - val_loss: 0.4421 - val_accuracy: 0.8026
# Epoch 45/100
# 6/6 [==============================] - 3s 546ms/step - loss: 3.9070e-04 - accuracy: 1.0000 - val_loss: 0.4338 - val_accuracy: 0.8026
# Epoch 46/100
# 6/6 [==============================] - 5s 821ms/step - loss: 4.3797e-04 - accuracy: 1.0000 - val_loss: 0.4359 - val_accuracy: 0.8026
# Epoch 47/100
# 6/6 [==============================] - 4s 573ms/step - loss: 3.3432e-04 - accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 0.8026
# Epoch 48/100
# 6/6 [==============================] - 3s 545ms/step - loss: 3.8486e-04 - accuracy: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.8026
# Epoch 49/100
# 6/6 [==============================] - 3s 537ms/step - loss: 3.3351e-04 - accuracy: 1.0000 - val_loss: 0.4844 - val_accuracy: 0.7895
# Epoch 50/100
# 6/6 [==============================] - 5s 847ms/step - loss: 5.3886e-04 - accuracy: 1.0000 - val_loss: 0.4666 - val_accuracy: 0.7895
# Epoch 51/100
# 6/6 [==============================] - 4s 541ms/step - loss: 2.4205e-04 - accuracy: 1.0000 - val_loss: 0.4388 - val_accuracy: 0.8026
# Epoch 52/100
# 6/6 [==============================] - 3s 545ms/step - loss: 2.6727e-04 - accuracy: 1.0000 - val_loss: 0.4324 - val_accuracy: 0.8026
# Epoch 53/100
# 6/6 [==============================] - 3s 549ms/step - loss: 2.3992e-04 - accuracy: 1.0000 - val_loss: 0.4289 - val_accuracy: 0.8158
# Epoch 54/100
# 6/6 [==============================] - 6s 1s/step - loss: 2.4146e-04 - accuracy: 1.0000 - val_loss: 0.4410 - val_accuracy: 0.8026
# Epoch 55/100
# 6/6 [==============================] - 3s 565ms/step - loss: 2.5126e-04 - accuracy: 1.0000 - val_loss: 0.4565 - val_accuracy: 0.8026
# Epoch 56/100
# 6/6 [==============================] - 3s 564ms/step - loss: 2.2165e-04 - accuracy: 1.0000 - val_loss: 0.4789 - val_accuracy: 0.8026
# Epoch 57/100
# 6/6 [==============================] - 3s 587ms/step - loss: 2.5554e-04 - accuracy: 1.0000 - val_loss: 0.4826 - val_accuracy: 0.8026
# Epoch 58/100
# 6/6 [==============================] - 5s 814ms/step - loss: 2.4824e-04 - accuracy: 1.0000 - val_loss: 0.4921 - val_accuracy: 0.8026
# Epoch 59/100
# 6/6 [==============================] - 3s 535ms/step - loss: 2.3687e-04 - accuracy: 1.0000 - val_loss: 0.4944 - val_accuracy: 0.8026
# Epoch 60/100
# 6/6 [==============================] - 3s 543ms/step - loss: 1.6809e-04 - accuracy: 1.0000 - val_loss: 0.5046 - val_accuracy: 0.8026
# Epoch 61/100
# 6/6 [==============================] - 4s 659ms/step - loss: 2.0133e-04 - accuracy: 1.0000 - val_loss: 0.5117 - val_accuracy: 0.8026
# Epoch 62/100
# 6/6 [==============================] - 5s 761ms/step - loss: 2.4495e-04 - accuracy: 1.0000 - val_loss: 0.5120 - val_accuracy: 0.8026
# Epoch 63/100
# 6/6 [==============================] - 3s 539ms/step - loss: 2.0733e-04 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.8026
# Epoch 64/100
# 6/6 [==============================] - 3s 549ms/step - loss: 2.3829e-04 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.8026
# Epoch 65/100
# 6/6 [==============================] - 4s 698ms/step - loss: 1.6762e-04 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.8026
# Epoch 66/100
# 6/6 [==============================] - 4s 698ms/step - loss: 1.9843e-04 - accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.8026
# Epoch 67/100
# 6/6 [==============================] - 3s 544ms/step - loss: 1.6286e-04 - accuracy: 1.0000 - val_loss: 0.4649 - val_accuracy: 0.8158
# Epoch 68/100
# 6/6 [==============================] - 3s 533ms/step - loss: 1.7557e-04 - accuracy: 1.0000 - val_loss: 0.4590 - val_accuracy: 0.8158
# Epoch 69/100
# 6/6 [==============================] - 4s 722ms/step - loss: 1.4963e-04 - accuracy: 1.0000 - val_loss: 0.4597 - val_accuracy: 0.8158
# Epoch 70/100
# 6/6 [==============================] - 4s 677ms/step - loss: 2.3894e-04 - accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.8158
# Epoch 71/100
# 6/6 [==============================] - 3s 540ms/step - loss: 2.4028e-04 - accuracy: 1.0000 - val_loss: 0.4527 - val_accuracy: 0.8026
# Epoch 72/100
# 6/6 [==============================] - 3s 544ms/step - loss: 1.5236e-04 - accuracy: 1.0000 - val_loss: 0.4526 - val_accuracy: 0.8026
# Epoch 73/100
# 6/6 [==============================] - 4s 756ms/step - loss: 1.6409e-04 - accuracy: 1.0000 - val_loss: 0.4438 - val_accuracy: 0.8026
# Epoch 74/100
# 6/6 [==============================] - 4s 641ms/step - loss: 1.4497e-04 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.8158
# Epoch 75/100
# 6/6 [==============================] - 3s 534ms/step - loss: 1.7330e-04 - accuracy: 1.0000 - val_loss: 0.4290 - val_accuracy: 0.8158
# Epoch 76/100
# 6/6 [==============================] - 3s 545ms/step - loss: 1.2046e-04 - accuracy: 1.0000 - val_loss: 0.4338 - val_accuracy: 0.8158
# Epoch 77/100
# 6/6 [==============================] - 4s 791ms/step - loss: 1.1622e-04 - accuracy: 1.0000 - val_loss: 0.4399 - val_accuracy: 0.8158
# Epoch 78/100
# 6/6 [==============================] - 4s 610ms/step - loss: 1.1530e-04 - accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.8158
# Epoch 79/100
# 6/6 [==============================] - 3s 551ms/step - loss: 1.1874e-04 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.8158
# Epoch 80/100
# 6/6 [==============================] - 3s 538ms/step - loss: 1.1480e-04 - accuracy: 1.0000 - val_loss: 0.4577 - val_accuracy: 0.8158
# Epoch 81/100
# 6/6 [==============================] - 5s 881ms/step - loss: 1.2905e-04 - accuracy: 1.0000 - val_loss: 0.4570 - val_accuracy: 0.8158
# Epoch 82/100
# 6/6 [==============================] - 4s 545ms/step - loss: 1.4461e-04 - accuracy: 1.0000 - val_loss: 0.4671 - val_accuracy: 0.8158
# Epoch 83/100
# 6/6 [==============================] - 3s 531ms/step - loss: 1.0363e-04 - accuracy: 1.0000 - val_loss: 0.4707 - val_accuracy: 0.8158
# Epoch 84/100
# 6/6 [==============================] - 3s 547ms/step - loss: 1.3525e-04 - accuracy: 1.0000 - val_loss: 0.4784 - val_accuracy: 0.8158
# Epoch 85/100
# 6/6 [==============================] - 5s 915ms/step - loss: 1.1332e-04 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.8158
# Epoch 86/100
# 6/6 [==============================] - 3s 544ms/step - loss: 1.4532e-04 - accuracy: 1.0000 - val_loss: 0.5096 - val_accuracy: 0.8158
# Epoch 87/100
# 6/6 [==============================] - 3s 535ms/step - loss: 1.3200e-04 - accuracy: 1.0000 - val_loss: 0.5123 - val_accuracy: 0.8158
# Epoch 88/100
# 6/6 [==============================] - 3s 536ms/step - loss: 8.9525e-05 - accuracy: 1.0000 - val_loss: 0.5048 - val_accuracy: 0.8158
# Epoch 89/100
# 6/6 [==============================] - 5s 939ms/step - loss: 9.6107e-05 - accuracy: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.8158
# Epoch 90/100
# 6/6 [==============================] - 3s 544ms/step - loss: 1.0198e-04 - accuracy: 1.0000 - val_loss: 0.5087 - val_accuracy: 0.8158
# Epoch 91/100
# 6/6 [==============================] - 3s 549ms/step - loss: 1.0090e-04 - accuracy: 1.0000 - val_loss: 0.5124 - val_accuracy: 0.8026
# Epoch 92/100
# 6/6 [==============================] - 3s 547ms/step - loss: 1.0364e-04 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.8026
# Epoch 93/100
# 6/6 [==============================] - 5s 904ms/step - loss: 8.9481e-05 - accuracy: 1.0000 - val_loss: 0.4951 - val_accuracy: 0.8026
# Epoch 94/100
# 6/6 [==============================] - 3s 536ms/step - loss: 9.4674e-05 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.8158
# Epoch 95/100
# 6/6 [==============================] - 5s 835ms/step - loss: 8.5420e-05 - accuracy: 1.0000 - val_loss: 0.4802 - val_accuracy: 0.8158
# Epoch 96/100
# 6/6 [==============================] - 6s 967ms/step - loss: 9.7932e-05 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.8158
# Epoch 97/100
# 6/6 [==============================] - 3s 545ms/step - loss: 9.3362e-05 - accuracy: 1.0000 - val_loss: 0.4765 - val_accuracy: 0.8158
# Epoch 98/100
# 6/6 [==============================] - 3s 536ms/step - loss: 8.4306e-05 - accuracy: 1.0000 - val_loss: 0.4750 - val_accuracy: 0.8158
# Epoch 99/100
# 6/6 [==============================] - 3s 546ms/step - loss: 1.2865e-04 - accuracy: 1.0000 - val_loss: 0.4740 - val_accuracy: 0.8158
# Epoch 100/100
# 6/6 [==============================] - 5s 932ms/step - loss: 8.7871e-05 - accuracy: 1.0000 - val_loss: 0.4684 - val_accuracy: 0.8158

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc = 'upper left')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train acc', 'test acc'], loc = 'upper left')
plt.show()

# %%
results = model.evaluate(x_test, y_test)
print('The current model achieved an accuracy of {}%!'.format(round(results[1]*100,2)))
# Out:
# 3/3 [==============================] - 0s 124ms/step - loss: 0.4684 - accuracy: 0.8158
# The current model achieved an accuracy of 81.58%!

# %%
filepath='/content/gdrive/MyDrive/Colab Notebooks/model storage/B01.h5'
model.save(
    filepath,
    overwrite=True,
    include_optimizer=True,
    save_format='h5',
    signatures=None,
    options=None,
    save_traces=True,
)
